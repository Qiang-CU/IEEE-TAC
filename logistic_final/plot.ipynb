# %%
import os 
import numpy as np
from util import plot_figure
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['ps.useafm'] = True
matplotlib.rcParams['pdf.use14corefonts'] = True
color_list = sns.color_palette()

# %%
data_dir = 'res/'

fig, ax = plt.subplots(figsize=(5.5, 5))

plot_csgd = plot_figure(algo_name=f'csgd', sub_sample=2, dir = data_dir , log_flag=True, metric='mse')
plot_csgd.plot_lines(ax, color_list[0], label='CSGD', legend=True, plot_star=True)

plot_csgd = plot_figure(algo_name=f'dsgd-homo-R', sub_sample=2, dir = data_dir , log_flag=True, metric='mse')
plot_csgd.plot_lines(ax, color_list[1], label='Homo-DSGD', legend=True, plot_star=True)

plot_csgd = plot_figure(algo_name=f'dsgd-hete-R', sub_sample=2, dir = data_dir , log_flag=True, metric='mse')
plot_csgd.plot_lines(ax, color_list[2], label='Hete-DSGD', legend=True, plot_star=True)

plt.grid(True)
# ax.set_xscale('linear')

# %%
data_dir = 'res/'

fig, ax = plt.subplots(figsize=(5.5, 5))

plot_csgd = plot_figure(algo_name=f'csgd', sub_sample=2, dir = data_dir , log_flag=True, metric='mse')
plot_csgd.plot_lines(ax, color_list[0], label='CSGD', legend=True, plot_star=True)

plot_csgd = plot_figure(algo_name=f'dsgd-homo-R', sub_sample=2, dir = data_dir , log_flag=True, metric='wmse')
plot_csgd.plot_lines(ax, color_list[1], label='Homo-DSGD', legend=True, plot_star=True)

plot_csgd = plot_figure(algo_name=f'dsgd-hete-R', sub_sample=2, dir = data_dir , log_flag=True, metric='wmse')
plot_csgd.plot_lines(ax, color_list[2], label='Hete-DSGD', legend=True, plot_star=True)

plt.grid(True)

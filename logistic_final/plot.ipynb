# %%
import os 
import numpy as np
from util import plot_figure
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['ps.useafm'] = True
matplotlib.rcParams['pdf.use14corefonts'] = True
color_list = sns.color_palette()

# %%
data_dir = 'res/'
ss = 1

fig, ax = plt.subplots(figsize=(5.5, 5))

plot_csgd = plot_figure(algo_name=f'csgd', sub_sample=ss, dir = data_dir , log_flag=True, metric='mse')
plot_csgd.plot_lines(ax, color_list[0], label='CSGD', legend=True, plot_star=True)

# plot_csgd = plot_figure(algo_name=f'dsgd-homo-R', sub_sample=ss, dir = data_dir , log_flag=True, metric='mse')
# plot_csgd.plot_lines(ax, color_list[1], label='Homo-DSGD', legend=True, plot_star=True)

plot_csgd = plot_figure(algo_name=f'dsgd-hete-R', sub_sample=ss, dir = data_dir , log_flag=True, metric='mse')
plot_csgd.plot_lines(ax, color_list[2], label='Hete-DSGD', legend=True, plot_star=True)

plt.grid(True)
# ax.set_xscale('linear')
# ax.ticklabel_format(style='sci', axis='x', scilimits=(0,1))

# %%
data_dir = 'res/'

fig, ax = plt.subplots(figsize=(5.5, 5))

plot_csgd = plot_figure(algo_name=f'csgd', sub_sample=ss, dir = data_dir , log_flag=True, metric='mse')
plot_csgd.plot_lines(ax, color_list[0], label='CSGD', legend=True, plot_star=True)

plot_csgd = plot_figure(algo_name=f'dsgd-homo-R', sub_sample=ss, dir = data_dir , log_flag=True, metric='wmse')
plot_csgd.plot_lines(ax, color_list[1], label='Homo-DSGD', legend=True, plot_star=True)

plot_csgd = plot_figure(algo_name=f'dsgd-hete-R', sub_sample=ss, dir = data_dir , log_flag=True, metric='wmse')
plot_csgd.plot_lines(ax, color_list[2], label='Hete-DSGD', legend=True, plot_star=True)

plt.grid(True)
ax.set_xscale('linear')
ax.ticklabel_format(style='sci', axis='x', scilimits=(0,1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 8
#       5 plot_csgd = plot_figure(algo_name=f'csgd', sub_sample=ss, dir = data_dir , log_flag=True, metric='mse')
#       6 plot_csgd.plot_lines(ax, color_list[0], label='CSGD', legend=True, plot_star=True)
# ----> 8 plot_csgd = plot_figure(algo_name=f'dsgd-homo-R', sub_sample=ss, dir = data_dir , log_flag=True, metric='wmse')
#       9 plot_csgd.plot_lines(ax, color_list[1], label='Homo-DSGD', legend=True, plot_star=True)
#      11 plot_csgd = plot_figure(algo_name=f'dsgd-hete-R', sub_sample=ss, dir = data_dir , log_flag=True, metric='wmse')
#
# File ~/TAC2/logistic_final/util.py:111, in plot_figure.__init__(self, algo_name, dir, sub_sample, log_flag, metric)
#     108 self.log_flag = log_flag
#     109 self.metric = metric
# --> 111 self.num_trails, self.res, self.xvals = self.load_data(algo_name)
#     112 self.z = 1.96/np.sqrt(self.num_trails)
#
# File ~/TAC2/logistic_final/util.py:119, in plot_figure.load_data(self, algo_name)
#     117 # 读取这些文件的数据
#     118 files = [np.load(os.path.join(self.dir, f), allow_pickle=True) for f in file]
# --> 119 xvals = files[0].item().get('iter')
#     121 num_points = int(1e3)
#     122 log_indices = np.logspace(0, np.log10(len(xvals) - 1), num=num_points).astype(int)
#
# IndexError: list index out of range
